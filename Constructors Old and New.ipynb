# %%
#load in libraies
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Load in required data
circuits = pd.read_csv("F1_Data_raw//circuits.csv")
lap_times = pd.read_csv("F1_data_raw//lap_times.csv")
races = pd.read_csv("F1_data_raw//races.csv")
qualifying = pd.read_csv("F1_data_raw//qualifying.csv")
results = pd.read_csv("F1_data_raw//results.csv")
drivers = pd.read_csv("F1_data_raw//drivers.csv")

constructor_results = pd.read_csv("F1_data_raw//constructor_results.csv")
constructor_standings = pd.read_csv("F1_data_raw//constructor_standings.csv")
constructors = pd.read_csv("F1_data_raw//constructors.csv")

silverstone_poles_data = pd.read_csv("Additional_Data//silverstone_poles_data.csv")
monza_poles_data = pd.read_csv("Additional_Data//monza_poles_data.csv")
monaco_poles_data = pd.read_csv("Additional_Data//monaco_poles_data.csv")

monaco_fastest_lap_data = pd.read_csv("Additional_Data//monaco_fastest_lap_data.csv")
monza_fastest_lap_data = pd.read_csv("Additional_Data//monza_fastest_lap_data.csv")
silverstone_fastest_lap_data = pd.read_csv("Additional_Data//silverstone_fastest_lap_data.csv")

# %% [markdown]
# # Cleaning up constructors data

# %%
constructor_results.head()
# Out:
#    constructorResultsId  raceId  constructorId  points status
# 0                     1      18              1    14.0    NaN
# 1                     2      18              2     8.0    NaN
# 2                     3      18              3     9.0    NaN
# 3                     4      18              4     5.0    NaN
# 4                     5      18              5     2.0    NaN

# %%
constructor_standings.head()
# Out:
#    constructorStandingsId  raceId  constructorId  points  position  \
# 0                       1      18              1    14.0         1
# 1                       2      18              2     8.0         3
# 2                       3      18              3     9.0         2
# 3                       4      18              4     5.0         4
# 4                       5      18              5     2.0         5
#
#   positionText  wins
# 0            1     1
# 1            3     0
# 2            2     0
# 3            4     0
# 4            5     0

# %%
constructors.head()
# Out:
#    constructorId constructorRef        name nationality  \
# 0              1        mclaren     McLaren     British
# 1              2     bmw_sauber  BMW Sauber      German
# 2              3       williams    Williams     British
# 3              4        renault     Renault      French
# 4              5     toro_rosso  Toro Rosso     Italian
#
#                                                  url
# 0               http://en.wikipedia.org/wiki/McLaren
# 1            http://en.wikipedia.org/wiki/BMW_Sauber
# 2  http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# 3  http://en.wikipedia.org/wiki/Renault_in_Formul...
# 4   http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso

# %%
#Rename to constructor name
constructors = constructors.rename(columns = {"name": "constructor_name"})
#Adding constructor name and ref to constructor results and standings


constructor_results = constructor_results.merge(constructors[["constructorId", "constructorRef", "constructor_name"]], on = "constructorId", how="left")
constructor_standings = constructor_standings.merge(constructors[["constructorId", "constructorRef", "constructor_name"]], on = "constructorId", how="left")

# %%
constructor_results.drop(columns = ["status"], inplace=True)
constructor_standings.drop(columns = ["positionText"], inplace=True)

constructor_results.head()
# Out:
#    constructorResultsId  raceId  constructorId  points constructorRef  \
# 0                     1      18              1    14.0        mclaren
# 1                     2      18              2     8.0     bmw_sauber
# 2                     3      18              3     9.0       williams
# 3                     4      18              4     5.0        renault
# 4                     5      18              5     2.0     toro_rosso
#
#   constructor_name
# 0          McLaren
# 1       BMW Sauber
# 2         Williams
# 3          Renault
# 4       Toro Rosso

# %%
constructor_standings.head()
# Out:
#    constructorStandingsId  raceId  constructorId  points  position  wins  \
# 0                       1      18              1    14.0         1     1
# 1                       2      18              2     8.0         3     0
# 2                       3      18              3     9.0         2     0
# 3                       4      18              4     5.0         4     0
# 4                       5      18              5     2.0         5     0
#
#   constructorRef constructor_name
# 0        mclaren          McLaren
# 1     bmw_sauber       BMW Sauber
# 2       williams         Williams
# 3        renault          Renault
# 4     toro_rosso       Toro Rosso

# %%
races.head()

# rename track name column
races = races.rename(columns = {"name": "track_name"})

# %%
#combining with races
constructor_results = constructor_results.merge(races[["raceId", "year", "circuitId", "track_name", "date"]], on = "raceId", how = "left")
constructor_standings = constructor_standings.merge(races[["raceId", "year", "circuitId", "track_name", "date"]], on = "raceId", how = "left")

# %%
constructor_results.head()
constructor_results.dtypes
# Out:
# constructorResultsId      int64
# raceId                    int64
# constructorId             int64
# points                  float64
# constructorRef           object
# constructor_name         object
# year                      int64
# circuitId                 int64
# track_name               object
# date                     object
# dtype: object

# %%
constructor_results.date = constructor_results.date.astype("datetime64")
constructor_results.dtypes
# Out:
# constructorResultsId             int64
# raceId                           int64
# constructorId                    int64
# points                         float64
# constructorRef                  object
# constructor_name                object
# year                             int64
# circuitId                        int64
# track_name                      object
# date                    datetime64[ns]
# dtype: object

# %%
#Order by date
constructor_results.sort_values(by=["date"],inplace=True)
constructor_results=constructor_results.reset_index()
constructor_results = constructor_results.drop(columns = ["index", "constructorResultsId" ])

#Rearrange columns
constructor_results = constructor_results[["date", "track_name", "circuitId" ,"year", "constructorId","constructorRef", "constructor_name", "raceId", "points"]]

constructor_results.head()
# Out:
#         date            track_name  circuitId  year  constructorId  \
# 0 1956-01-22  Argentine Grand Prix         25  1956            105
# 1 1956-01-22  Argentine Grand Prix         25  1956              6
# 2 1956-08-05     German Grand Prix         20  1956            128
# 3 1956-08-05     German Grand Prix         20  1956            105
# 4 1956-08-05     German Grand Prix         20  1956              6
#
#   constructorRef constructor_name  raceId  points
# 0       maserati         Maserati     784    13.0
# 1        ferrari          Ferrari     784    12.0
# 2        gordini          Gordini     790     0.0
# 3       maserati         Maserati     790    15.0
# 4        ferrari          Ferrari     790     9.0

# %%
#Cleaning up and reordering constructor standings table 
constructor_standings.date = constructor_standings.date.astype("datetime64")
constructor_standings.sort_values(by=["date"],inplace=True)
constructor_standings=constructor_standings.reset_index()
constructor_standings = constructor_standings.rename(columns = {"points": "total_points"})

constructor_standings = constructor_standings[["date", "track_name", "circuitId" ,"year", "constructorId","constructorRef", "constructor_name", "raceId", "total_points", "position", "wins"]]

constructor_standings.head(20)
# Out:
#          date            track_name  circuitId  year  constructorId  \
# 0  1958-01-19  Argentine Grand Prix         25  1958            105
# 1  1958-01-19  Argentine Grand Prix         25  1958              6
# 2  1958-01-19  Argentine Grand Prix         25  1958             87
# 3  1958-05-18     Monaco Grand Prix          6  1958             87
# 4  1958-05-18     Monaco Grand Prix          6  1958             32
# 5  1958-05-18     Monaco Grand Prix          6  1958             66
# 6  1958-05-18     Monaco Grand Prix          6  1958            105
# 7  1958-05-18     Monaco Grand Prix          6  1958              6
# 8  1958-05-18     Monaco Grand Prix          6  1958            127
# 9  1958-05-18     Monaco Grand Prix          6  1958            118
# 10 1958-05-18     Monaco Grand Prix          6  1958            125
# 11 1958-05-26      Dutch Grand Prix         39  1958            118
# 12 1958-05-26      Dutch Grand Prix         39  1958             95
# 13 1958-05-26      Dutch Grand Prix         39  1958            127
# 14 1958-05-26      Dutch Grand Prix         39  1958            125
# 15 1958-05-26      Dutch Grand Prix         39  1958             66
# 16 1958-05-26      Dutch Grand Prix         39  1958             32
# 17 1958-05-26      Dutch Grand Prix         39  1958            105
# 18 1958-05-26      Dutch Grand Prix         39  1958              6
# 19 1958-05-26      Dutch Grand Prix         39  1958             87
#
#    constructorRef constructor_name  raceId  total_points  position  wins
# 0        maserati         Maserati     765           3.0         3     0
# 1         ferrari          Ferrari     765           6.0         2     0
# 2          cooper           Cooper     765           8.0         1     1
# 3          cooper           Cooper     766          16.0         1     2
# 4      team_lotus       Team Lotus     766           0.0         5     0
# 5             brm              BRM     766           2.0         4     0
# 6        maserati         Maserati     766           3.0         3     0
# 7         ferrari          Ferrari     766          12.0         2     0
# 8            osca             OSCA     766           0.0         8     0
# 9         vanwall          Vanwall     766           0.0         6     0
# 10      connaught        Connaught     766           0.0         7     0
# 11        vanwall          Vanwall     767           8.0         3     1
# 12        porsche          Porsche     767           0.0         7     0
# 13           osca             OSCA     767           0.0         9     0
# 14      connaught        Connaught     767           0.0         8     0
# 15            brm              BRM     767           8.0         4     0
# 16     team_lotus       Team Lotus     767           0.0         6     0
# 17       maserati         Maserati     767           3.0         5     0
# 18        ferrari          Ferrari     767          14.0         2     0
# 19         cooper           Cooper     767          19.0         1     2

# %%
constructor_standings[constructor_standings.year == 1958].date.idxmax()
# Out:
# 83

# %%
constructor_standings.iloc[83][7]
# Out:
# 775

# %%
standings_1958 = constructor_standings[constructor_standings.raceId == 775]
standings_1958 = standings_1958[["year","constructorId", "constructorRef" ,"constructor_name", "total_points","position", "wins"]].reset_index(drop=True)
standings_1958.sort_values(by = ["position"], inplace= True)

# %%
standings_1958
# Out:
#    year  constructorId constructorRef constructor_name  total_points  \
# 0  1958            118        vanwall          Vanwall          48.0
# 8  1958              6        ferrari          Ferrari          40.0
# 1  1958             87         cooper           Cooper          31.0
# 5  1958             66            brm              BRM          18.0
# 6  1958            105       maserati         Maserati           6.0
# 2  1958             32     team_lotus       Team Lotus           3.0
# 4  1958             95        porsche          Porsche           0.0
# 3  1958            125      connaught        Connaught           0.0
# 7  1958            127           osca             OSCA           0.0
#
#    position  wins
# 0         1     6
# 8         2     2
# 1         3     2
# 5         4     0
# 6         5     0
# 2         6     0
# 4         7     0
# 3         8     0
# 7         9     0

# %%
#results for up to the last full year as 2022
constructors_results_by_year = standings_1958
for i in range(1959,2023):
    #grab race id for last in season
    last_race_index = constructor_standings[constructor_standings.year == i].date.idxmax()
    raceId = constructor_standings.iloc[last_race_index][7]
    ith_year_df = constructor_standings[constructor_standings.raceId == raceId]
    ith_year_df = ith_year_df[["year","constructorId", "constructorRef" ,"constructor_name", "total_points","position", "wins"]].reset_index(drop=True)
    ith_year_df.sort_values(by = ["position"], inplace= True)
    constructors_results_by_year = pd.concat([constructors_results_by_year,ith_year_df])

# %%
constructors_results_by_year
# Out:
#     year  constructorId constructorRef constructor_name  total_points  \
# 0   1958            118        vanwall          Vanwall          48.0
# 8   1958              6        ferrari          Ferrari          40.0
# 1   1958             87         cooper           Cooper          31.0
# 5   1958             66            brm              BRM          18.0
# 6   1958            105       maserati         Maserati           6.0
# ..   ...            ...            ...              ...           ...
# 6   2022             51           alfa       Alfa Romeo          55.0
# 0   2022            117   aston_martin     Aston Martin          55.0
# 7   2022            210           haas     Haas F1 Team          37.0
# 4   2022            213     alphatauri       AlphaTauri          35.0
# 3   2022              3       williams         Williams           8.0
#
#     position  wins
# 0          1     6
# 8          2     2
# 1          3     2
# 5          4     0
# 6          5     0
# ..       ...   ...
# 6          6     0
# 0          7     0
# 7          8     0
# 4          9     0
# 3         10     0
#
# [900 rows x 7 columns]

# %%
hass = constructors_results_by_year[(constructors_results_by_year.constructorRef == "haas") & (constructors_results_by_year.year <= 1980)]
len(hass)
# Out:
# 0

# %%
constructors_results_by_year.dtypes
# Out:
# year                  int64
# constructorId         int64
# constructorRef       object
# constructor_name     object
# total_points        float64
# position              int64
# wins                  int64
# dtype: object

# %%
constructors_results_by_year.shape
# Out:
# (900, 7)

# %% [markdown]
# # Exporting constructor results as csv

# %%
constructors_results_by_year.to_csv("constructors_results_by_year.csv", index = False)

# %%
#Creating winners table and exporting
constructors_winners = constructors_results_by_year[constructors_results_by_year.position == 1].drop(columns = ["position", "wins", "total_points"]).reset_index(drop=True)

# %%
constructors_winners.head()
# Out:
#    year  constructorId constructorRef constructor_name
# 0  1958            118        vanwall          Vanwall
# 1  1959            170  cooper-climax    Cooper-Climax
# 2  1960            170  cooper-climax    Cooper-Climax
# 3  1961              6        ferrari          Ferrari
# 4  1962             66            brm              BRM

# %%
#Export csv
constructors_winners.to_csv("constructors_winners.csv", index = False)

# %% [markdown]
# # New Constructors since 2000 we'll explore

# %% [markdown]
# - Red Bull
# - Haas
# - Force India/Racing Point/Aston Martin
# - Mercedes
# - Caterham Racing
# - Virgin/Marussia/Manor
# - Toyota
# - Super Aguri
# - HRT

# %%
constructors_results_by_year.head()
# Out:
#    year  constructorId constructorRef constructor_name  total_points  \
# 0  1958            118        vanwall          Vanwall          48.0
# 8  1958              6        ferrari          Ferrari          40.0
# 1  1958             87         cooper           Cooper          31.0
# 5  1958             66            brm              BRM          18.0
# 6  1958            105       maserati         Maserati           6.0
#
#    position  wins
# 0         1     6
# 8         2     2
# 1         3     2
# 5         4     0
# 6         5     0

# %%
#Group Force India/Racing Point/Aston Martin into 1 entry
force_india = constructors_results_by_year[constructors_results_by_year.constructorRef == "force_india"]
force_india = force_india.assign(constructor_name = "Aston Grouped")
force_india = force_india.assign(constructorRef = "aston_grouped")

# %%
force_india
# Out:
#    year  constructorId constructorRef constructor_name  total_points  \
# 3  2008             10  aston_grouped    Aston Grouped           0.0
# 9  2009             10  aston_grouped    Aston Grouped          13.0
# 9  2010             10  aston_grouped    Aston Grouped          68.0
# 2  2011             10  aston_grouped    Aston Grouped          69.0
# 4  2012             10  aston_grouped    Aston Grouped         109.0
# 5  2013             10  aston_grouped    Aston Grouped          77.0
# 6  2014             10  aston_grouped    Aston Grouped         155.0
# 8  2015             10  aston_grouped    Aston Grouped         136.0
# 5  2016             10  aston_grouped    Aston Grouped         173.0
# 4  2017             10  aston_grouped    Aston Grouped         187.0
# 2  2018             10  aston_grouped    Aston Grouped          52.0
#
#    position  wins
# 3        10     0
# 9         9     0
# 9         7     0
# 2         6     0
# 4         7     0
# 5         6     0
# 6         6     0
# 8         5     0
# 5         4     0
# 4         4     0
# 2         7     0

# %%
racing_point = constructors_results_by_year[constructors_results_by_year.constructorRef == "racing_point"]
racing_point = racing_point.assign(constructor_name = "Aston Grouped")
racing_point = racing_point.assign(constructorRef = "aston_grouped")

racing_point
# Out:
#    year  constructorId constructorRef constructor_name  total_points  \
# 9  2019            211  aston_grouped    Aston Grouped          73.0
# 9  2020            211  aston_grouped    Aston Grouped         195.0
#
#    position  wins
# 9         7     0
# 9         4     1

# %%
aston_martin = constructors_results_by_year[(constructors_results_by_year.constructorRef == "aston_martin") & (constructors_results_by_year.year >= 2000)]
aston_martin = aston_martin.assign(constructor_name = "Aston Grouped")
aston_martin = aston_martin.assign(constructorRef = "aston_grouped")

aston_martin
# Out:
#    year  constructorId constructorRef constructor_name  total_points  \
# 4  2021            117  aston_grouped    Aston Grouped          77.0
# 0  2022            117  aston_grouped    Aston Grouped          55.0
#
#    position  wins
# 4         7     0
# 0         7     0

# %%
#Concat the frames
new_constructors = pd.concat([force_india,racing_point,aston_martin ])
new_constructors
# Out:
#    year  constructorId constructorRef constructor_name  total_points  \
# 3  2008             10  aston_grouped    Aston Grouped           0.0
# 9  2009             10  aston_grouped    Aston Grouped          13.0
# 9  2010             10  aston_grouped    Aston Grouped          68.0
# 2  2011             10  aston_grouped    Aston Grouped          69.0
# 4  2012             10  aston_grouped    Aston Grouped         109.0
# 5  2013             10  aston_grouped    Aston Grouped          77.0
# 6  2014             10  aston_grouped    Aston Grouped         155.0
# 8  2015             10  aston_grouped    Aston Grouped         136.0
# 5  2016             10  aston_grouped    Aston Grouped         173.0
# 4  2017             10  aston_grouped    Aston Grouped         187.0
# 2  2018             10  aston_grouped    Aston Grouped          52.0
# 9  2019            211  aston_grouped    Aston Grouped          73.0
# 9  2020            211  aston_grouped    Aston Grouped         195.0
# 4  2021            117  aston_grouped    Aston Grouped          77.0
# 0  2022            117  aston_grouped    Aston Grouped          55.0
#
#    position  wins
# 3        10     0
# 9         9     0
# 9         7     0
# 2         6     0
# 4         7     0
# 5         6     0
# 6         6     0
# 8         5     0
# 5         4     0
# 4         4     0
# 2         7     0
# 9         7     0
# 9         4     1
# 4         7     0
# 0         7     0

# %%
#Same Process for Virgin/Marussia/Manor
virgin = constructors_results_by_year[constructors_results_by_year.constructorRef == "virgin"]
virgin = virgin.assign(constructor_name = "Manor Grouped")
virgin = virgin.assign(constructorRef = "manor_grouped")

marussia = constructors_results_by_year[constructors_results_by_year.constructorRef == "marussia"]
marussia = marussia.assign(constructor_name = "Manor Grouped")
marussia = marussia.assign(constructorRef = "manor_grouped")

manor = constructors_results_by_year[constructors_results_by_year.constructorRef == "manor"]
manor = manor.assign(constructor_name = "Manor Grouped")
manor = manor.assign(constructorRef = "manor_grouped")

new_constructors = pd.concat([new_constructors, virgin,marussia,manor ])
new_constructors
# Out:
#    year  constructorId constructorRef constructor_name  total_points  \
# 3  2008             10  aston_grouped    Aston Grouped           0.0
# 9  2009             10  aston_grouped    Aston Grouped          13.0
# 9  2010             10  aston_grouped    Aston Grouped          68.0
# 2  2011             10  aston_grouped    Aston Grouped          69.0
# 4  2012             10  aston_grouped    Aston Grouped         109.0
# 5  2013             10  aston_grouped    Aston Grouped          77.0
# 6  2014             10  aston_grouped    Aston Grouped         155.0
# 8  2015             10  aston_grouped    Aston Grouped         136.0
# 5  2016             10  aston_grouped    Aston Grouped         173.0
# 4  2017             10  aston_grouped    Aston Grouped         187.0
# 2  2018             10  aston_grouped    Aston Grouped          52.0
# 9  2019            211  aston_grouped    Aston Grouped          73.0
# 9  2020            211  aston_grouped    Aston Grouped         195.0
# 4  2021            117  aston_grouped    Aston Grouped          77.0
# 0  2022            117  aston_grouped    Aston Grouped          55.0
# 1  2010            166  manor_grouped    Manor Grouped           0.0
# 3  2011            166  manor_grouped    Manor Grouped           0.0
# 7  2012            206  manor_grouped    Manor Grouped           0.0
# 0  2013            206  manor_grouped    Manor Grouped           0.0
# 3  2014            206  manor_grouped    Manor Grouped           2.0
# 6  2015            209  manor_grouped    Manor Grouped           0.0
# 1  2016            209  manor_grouped    Manor Grouped           1.0
#
#    position  wins
# 3        10     0
# 9         9     0
# 9         7     0
# 2         6     0
# 4         7     0
# 5         6     0
# 6         6     0
# 8         5     0
# 5         4     0
# 4         4     0
# 2         7     0
# 9         7     0
# 9         4     1
# 4         7     0
# 0         7     0
# 1        12     0
# 3        12     0
# 7        11     0
# 0        10     0
# 3         9     0
# 6        10     0
# 1        11     0

# %%
other_teams = constructors_results_by_year[(constructors_results_by_year.constructorRef == "red_bull")
                             | (constructors_results_by_year.constructorRef == "haas")
                             | (constructors_results_by_year.constructorRef == "mercedes")
                             | (constructors_results_by_year.constructorRef == "hrt")
                             | (constructors_results_by_year.constructorRef == "caterham")
                             | (constructors_results_by_year.constructorRef == "toyota")
                             | (constructors_results_by_year.constructorRef == "super_aguri")
                            ]

# %%
new_constructors = pd.concat([new_constructors,other_teams  ]).reset_index(drop=True)
new_constructors = new_constructors.sort_values("year").reset_index(drop=True)
new_constructors.head()
# Out:
#    year  constructorId constructorRef constructor_name  total_points  \
# 0  2002              7         toyota           Toyota           2.0
# 1  2003              7         toyota           Toyota          16.0
# 2  2004              7         toyota           Toyota           9.0
# 3  2005              7         toyota           Toyota          88.0
# 4  2005              9       red_bull         Red Bull          34.0
#
#    position  wins
# 0        10     0
# 1         8     0
# 2         8     0
# 3         4     0
# 4         7     0

# %%
#Export new_constructors data
new_constructors.to_csv("new_constructors.csv", index = False)
